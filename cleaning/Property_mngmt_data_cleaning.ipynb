# %%
import pandas as pd

# %%
df=pd.read_csv("../data/greece_listings.csv")
df.shape
# Out:
# (20000, 25)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    location_name location_region    res_date    res_type  \
# 0  Παλαιό Φάληρο          Αττική  2021-06-18  Διαμέρισμα
# 1        Αχαρνές          Αττική  2022-03-30    Μεζονέτα
# 2       Παγκράτι          Αττική  2022-02-25  Διαμέρισμα
# 3          Αθήνα          Αττική  2022-03-21  Διαμέρισμα
# 4          Ίλιον          Αττική  2022-01-11  Διαμέρισμα
#
#                  res_address  res_price  res_price_sqr  res_sqr  \
# 0       Παλαιό Φάληρο,Γήπεδα      89000         1618.0     55.0
# 1              Αχαρνές,Λαθέα     150000         1531.0     98.0
# 2             Αθήνα,Παγκράτι     400000         3175.0    126.0
# 3  Αθήνα,Άγιος Παντελεήμονας      80000          941.0     85.0
# 4     Αθήνα,Άγιος Ελευθέριος     100000         2083.0     48.0
#
#    construction_year       levels  bedrooms  bathrooms  deleted  \
# 0             1973.0  Υπερυψωμένο       1.0        1.0        1
# 1             2010.0          4ος       2.0        1.0        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   location_name      20000 non-null  str
#  1   location_region    20000 non-null  str
#  2   res_date           20000 non-null  str
#  3   res_type           20000 non-null  str
#  4   res_address        20000 non-null  str
#  5   res_price          20000 non-null  int64
#  6   res_price_sqr      19998 non-null  float64
#  7   res_sqr            19999 non-null  float64
#  8   construction_year  19214 non-null  float64
#  9   levels             19992 non-null  str
#  10  bedrooms           18935 non-null  float64
#  11  bathrooms          18214 non-null  float64
#  12  deleted            20000 non-null  int64
#  13  deleted_at         16885 non-null  str
#  14  status             18195 non-null  str
#  15  energyclass        18186 non-null  str
# ...
